# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ### Import Libraries

# %%
# %matplotlib inline
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression 
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %% [markdown]
# ### Import Dataset

# %%
data = pd.read_csv(r"C:\Users\Akunna Anyamkpa\Documents\HAMOYE\PROJECT 3\energy.csv")

# %%
data.head(4)
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0    92.0   7.000000   63.000000        5.3  13.275433  13.275433
# 1    92.0   6.666667   59.166667        5.2  18.606195  18.606195
# 2    92.0   6.333333   55.333333        5.1  28.642668  28.642668
# 3    92.0   6.000000   51.500000        5.0  45.410389  45.410389
#
# [4 rows x 29 columns]

# %%
data.shape
# Out:
# (19735, 29)

# %% [markdown]
# ### View Columns

# %%
data.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %% [markdown]
# ### Check for datatypes and missing values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
#  18  RH_8         19735 non-null  float64
#  19  T9           19735 non-null  float64
#  20  RH_9         19735 non-null  float64
#  21  T_out        19735 non-null  float64
#  22  Press_mm_hg  19735 non-null  float64
#  23  RH_out       19735 non-null  float64
#  24  Windspeed    19735 non-null  float64
#  25  Visibility   19735 non-null  float64
#  26  Tdewpoint    19735 non-null  float64
#  27  rv1          19735 non-null  float64
#  28  rv2          19735 non-null  float64
# dtypes: float64(26), int64(2), object(1)
# memory usage: 4.4+ MB

# %%
data.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %% [markdown]
# ## Data Profiling

# %% [markdown]
# ### Checking for outliers

# %%
data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# std        4.069813      2.006111      3.254576      2.042884      4.341321
# min       20.463333     17.200000     28.766667     15.100000     27.660000
# 25%       37.900000     20.790000     36.900000     19.530000     35.530000
# 50%       40.500000     22.100000     38.530000     20.666667     38.400000
# 75%       43.260000     23.290000     41.760000     22.100000     42.156667
# max       56.026667     29.236000     50.163333     26.200000     51.090000
#
#        ...            T9          RH_9         T_out   Press_mm_hg  \
# count  ...  19735.000000  19735.000000  19735.000000  19735.000000
# mean   ...     19.485828     41.552401      7.411665    755.522602
# std    ...      2.014712      4.151497      5.317409      7.399441
# min    ...     14.890000     29.166667     -5.000000    729.300000
# 25%    ...     18.000000     38.500000      3.666667    750.933333
# 50%    ...     19.390000     40.900000      6.916667    756.100000
# 75%    ...     20.600000     44.338095     10.408333    760.933333
# max    ...     24.500000     53.326667     26.100000    772.300000
#
#              RH_out     Windspeed    Visibility     Tdewpoint           rv1  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      79.750418      4.039752     38.330834      3.760707     24.988033
# std       14.901088      2.451221     11.794719      4.194648     14.496634
# min       24.000000      0.000000      1.000000     -6.600000      0.005322
# 25%       70.333333      2.000000     29.000000      0.900000     12.497889
# 50%       83.666667      3.666667     40.000000      3.433333     24.897653
# 75%       91.666667      5.500000     40.000000      6.566667     37.583769
# max      100.000000     14.000000     66.000000     15.500000     49.996530
#
#                 rv2
# count  19735.000000
# mean      24.988033
# std       14.496634
# min        0.005322
# 25%       12.497889
# 50%       24.897653
# 75%       37.583769
# max       49.996530
#
# [8 rows x 28 columns]

# %%
data.lights.value_counts()
# Out:
# 0     15252
# 10     2212
# 20     1624
# 30      559
# 40       77
# 50        9
# 70        1
# 60        1
# Name: lights, dtype: int64

# %% [markdown]
# ### Drop columns

# %%
data.drop('date', axis='columns', inplace=True)
data.drop('lights', axis='columns', inplace=True)

# %%
data['zscore'] = ( data.Windspeed - data.Windspeed.mean() ) / data.Windspeed.std()
data.head(5)
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...   RH_9     T_out  Press_mm_hg  RH_out  Windspeed  \
# 0  45.566667  17.166667  ...  45.53  6.600000        733.5    92.0   7.000000
# 1  45.992500  17.166667  ...  45.56  6.483333        733.6    92.0   6.666667
# 2  45.890000  17.166667  ...  45.50  6.366667        733.7    92.0   6.333333
# 3  45.723333  17.166667  ...  45.40  6.250000        733.8    92.0   6.000000
# 4  45.530000  17.200000  ...  45.40  6.133333        733.9    92.0   5.666667
#
#    Visibility  Tdewpoint        rv1        rv2    zscore
# 0   63.000000        5.3  13.275433  13.275433  1.207663
# 1   59.166667        5.2  18.606195  18.606195  1.071676
# 2   55.333333        5.1  28.642668  28.642668  0.935690
# 3   51.500000        5.0  45.410389  45.410389  0.799703
# 4   47.666667        4.9  10.084097  10.084097  0.663716
#
# [5 rows x 28 columns]

# %%
data[(data.zscore<-3) | (data.zscore>3)]
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 2661           40  19.230000  44.126667  18.500000  43.900000  19.790000
# 2662           40  19.200000  44.090000  18.500000  43.900000  19.790000
# 2663           50  19.200000  44.163333  18.500000  44.030000  19.790000
# 2664           40  19.166667  44.200000  18.426667  44.030000  19.790000
# 2665           50  19.100000  44.200000  18.390000  44.030000  19.890000
# ...           ...        ...        ...        ...        ...        ...
# 11045         110  21.390000  40.590000  18.790000  45.000000  22.390000
# 11046         100  21.390000  40.730000  18.790000  45.000000  22.390000
# 11047          90  21.390000  40.863333  18.890000  45.000000  22.390000
# 11048         110  21.426667  40.860000  18.963333  45.000000  22.323333
# 11049          90  21.500000  41.000000  19.263333  44.766667  22.390000
#
#             RH_3         T4       RH_4         T5  ...       RH_9     T_out  \
# 2661   44.663333  16.600000  46.500000  16.700000  ...  48.790000  8.900000
# 2662   44.663333  16.533333  46.530000  16.700000  ...  48.790000  8.833333
# 2663   44.700000  16.533333  46.590000  16.700000  ...  48.790000  8.766667
# 2664   44.700000  16.500000  46.590000  16.700000  ...  48.900000  8.700000
# 2665   44.826667  16.500000  46.590000  16.700000  ...  48.900000  8.666667
# ...          ...        ...        ...        ...  ...        ...       ...
# 11045  37.900000  20.000000  40.260000  19.790000  ...  42.200000  8.850000
# 11046  37.966667  20.263333  40.626667  19.790000  ...  42.090000  8.900000
# 11047  38.090000  20.530000  40.760000  19.856667  ...  42.090000  8.850000
# 11048  38.090000  20.860000  40.900000  19.856667  ...  41.966667  8.800000
# 11049  38.126667  21.066667  40.900000  19.790000  ...  41.826667  8.750000
#
#        Press_mm_hg  RH_out  Windspeed  Visibility  Tdewpoint        rv1  \
# 2661    756.400000    85.0  11.500000   40.000000   6.500000   9.316703
# 2662    756.300000    86.0  11.666667   40.000000   6.600000  10.221086
# 2663    756.200000    87.0  11.833333   40.000000   6.700000  11.592651
# 2664    756.100000    88.0  12.000000   40.000000   6.800000  20.305092
# 2665    756.000000    89.0  11.833333   41.000000   6.916667  43.358476
# ...            ...     ...        ...         ...        ...        ...
# 11045   739.166667    82.0  12.166667   38.000000   5.950000  10.962173
# 11046   739.100000    83.0  12.000000   40.000000   6.200000   9.382576
# 11047   739.216667    84.5  11.833333   43.833333   6.383333  25.963221
# 11048   739.333333    86.0  11.666667   47.666667   6.566667  21.774027
# 11049   739.450000    87.5  11.500000   51.500000   6.750000  35.932348
#
#              rv2    zscore
# 2661    9.316703  3.043483
# 2662   10.221086  3.111476
# 2663   11.592651  3.179470
# 2664   20.305092  3.247463
# 2665   43.358476  3.179470
# ...          ...       ...
# 11045  10.962173  3.315456
# 11046   9.382576  3.247463
# 11047  25.963221  3.179470
# 11048  21.774027  3.111476
# 11049  35.932348  3.043483
#
# [104 rows x 28 columns]

# %% [markdown]
# ## MODEL BUILDING

# %% [markdown]
# ### Feature Correlation

# %%
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_803a6_row0_col0,#T_803a6_row1_col1,#T_803a6_row2_col2,#T_803a6_row3_col3,#T_803a6_row4_col4,#T_803a6_row5_col5,#T_803a6_row6_col6,#T_803a6_row7_col7,#T_803a6_row8_col8,#T_803a6_row9_col9,#T_803a6_row10_col10,#T_803a6_row11_col11,#T_803a6_row12_col12,#T_803a6_row13_col13,#T_803a6_row14_col14,#T_803a6_row15_col15,#T_803a6_row16_col16,#T_803a6_row17_col17,#T_803a6_row18_col18,#T_803a6_row19_col19,#T_803a6_row20_col20,#T_803a6_row21_col21,#T_803a6_row22_col22,#T_803a6_row22_col27,#T_803a6_row23_col23,#T_803a6_row24_col24,#T_803a6_row25_col25,#T_803a6_row25_col26,#T_803a6_row26_col25,#T_803a6_row26_col26,#T_803a6_row27_col22,#T_803a6_row27_col27{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_803a6_row0_col1,#T_803a6_row12_col2,#T_803a6_row23_col21{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T

#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_803a6_row1_col3,#T_803a6_row1_col15,#T_803a6_row9_col15{
#             background-color:  #d75445;
#             color:  #000000;
#         }#T_803a6_row1_col5,#T_803a6_row7_col17,#T_803a6_row17_col7{
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }#T_803a6_row1_col6,#T_803a6_row9_col16,#T_803a6_row11_col4,#T_803a6_row12_col23,#T_803a6_row21_col13,#T_803a6_row22_col10,#T_803a6_row25_col8,#T_803a6_row26_col8,#T_803a6_row27_col10{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_803a6_row1_col7,#T_803a6_row9_col1,#T_803a6_row9_col13,#T_803a6_row13_col7,#T_803a6_row13_col15{
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }#T_803a6_row1_col8,#T_803a6_row11_col6,#T_803a6_row19_col16,#T_803a6_row20_col5{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_803a6_row1_col9,#T_803a6_row5_col1,#T_803a6_row5_col9,#T_803a6_row7_col13,#T_803a6_row9_col5,#T_803a6_row15_col13{
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }#T_803a6_row1_col11,#T_803a6_row7_col19,#T_803a6_row11_col7,#T_803a6_row16_col2,#T_803a6_row17_col3{
#             background-color:  #ee8669;
#             color:  #000000;
#         }#T_803a6_row1_col12,#T_803a6_row2_col23,#T_803a6_row4_col0,#T_803a6_row5_col20,#T_803a6_row19_col10{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_803a6_row1_col13,#T_803a6_row8_col2,#T_803a6_row13_col5,#T_803a6_row16_col14{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_803a6_row1_col14,#T_803a6_row20_col11{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_803a6_row1_col16,#T_803a6_row12_col20{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_803a6_row1_col17,#T_803a6_row5_col7,#T_803a6_row5_col13,#T_803a6_row7_col5{
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }#T_803a6_row1_col18,#T_803a6_row9_col18,#T_803a6_row19_col0{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_803a6_row1_col19,#T_803a6_row3_col13{
#             background-color:  #ec8165;
#             color:  #000000;
#         }#T_803a6_row1_col21,#T_803a6_row8_col0,#T_803a6_row17_col18,#T_803a6_row24_col0{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_803a6_row1_col22,#T_803a6_row1_col27,#T_803a6_row7_col21,#T_803a6_row11_col20{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_803a6_row1_col23,#T_803a6_row4_col20,#T_803a6_row7_col12,#T_803a6_row19_col23{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_803a6_row1_col24{
#             background-color:  #f7ba9f;
#             c

# %% [markdown]
# ### Feature Engineering

# %%
# INPUT-FEATURES_INDEPENDENT VARIABLE
#x = data.drop(columns = ['Appliances']) # When input is all features except appliances
x = data[['RH_1','T2','T3','T6','T_out','Windspeed','RH_8','RH_6']]

# OUTPUT FEATURE_DEPENDANT VARIABLE 
y = data['Appliances'] #target variable

# %%
x.columns
# Out:
# Index(['RH_1', 'T2', 'T3', 'T6', 'T_out', 'Windspeed', 'RH_8', 'RH_6'], dtype='object')

# %% [markdown]
# ### Feature Scaling

# %%
Scaler = StandardScaler() 

scaled = Scaler.fit_transform(x) 
scaled
# Out:
# array([[ 1.84382063, -0.52041138, -1.23506343, ...,  1.20769354,
#          1.14157236,  0.95179837],
#        [ 1.61680671, -0.52041138, -1.23506343, ...,  1.07170342,
#          1.13455378,  0.94559165],
#        [ 1.51795932, -0.52041138, -1.23506343, ...,  0.93571331,
#          1.10903167,  0.91648425],
#        ...,
#        [ 1.59251371,  2.41110339,  2.38397142, ..., -0.15220764,
#          1.28704839, -1.72105219],
#        [ 1.6913611 ,  2.31325594,  2.30421308, ..., -0.08421258,
#          1.2600109 , -1.72105219],
#        [ 1.5933514 ,  2.24498422,  2.27098043, ..., -0.01621752,
#          1.30159599, -1.72105219]])

# %% [markdown]
# ### Split to train and test data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %% [markdown]
# ### Linear Regressor

# %%
# Define the range of hyperparameters
params = {
    'fit_intercept': [True, False],
    'copy_X': [True, False],
}
# Create a linear regression object
lr = LinearRegression()

# Perform GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(lr, param_grid=params, scoring='neg_mean_squared_error', cv=5)
grid_search.fit(x_train, y_train)

# Print the best hyperparameters and the corresponding MSE
print("Best hyperparameters: ", grid_search.best_params_)
# Out:
# Best hyperparameters:  {'copy_X': True, 'fit_intercept': True}

# %%
# Train the model
lr = LinearRegression(copy_X= True, fit_intercept= True)

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Prediction
predicted = lr.predict(x_test)
predicted[0]
# Out:
# 64.11202597405389

# %%
print(r2_score(y_test, predicted).round(2)*100,"%") # R-Squared Evaluation Technique
# Out:
# 8.0 %

# %% [markdown]
# ### Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbt = GradientBoostingRegressor(learning_rate=0.1)

y_train_col = y_train.ravel()

gbt = gbt.fit(x_train, y_train_col)

# %%
# Accuracy score
gbt.score(x_test, y_test)
# Out:
# 0.17643108825654885

# %% [markdown]
# ### Support Vector Machine

# %%
from sklearn.svm import SVR

sv = SVR(kernel = 'rbf')

y_train_col = y_train.ravel()

sv.fit(x_train, y_train_col)
# Out:
# SVR()

# %%
# Accuracy score
sv.score(x_test, y_test)
# Out:
# -0.05575408127021819

# %% [markdown]
# ### Decision Tree Regressor

# %%
param_grid = {'max_depth': [2, 4, 6, 8, 10],
              'min_samples_leaf': [1, 2, 4, 6, 8]}

dt = DecisionTreeRegressor()

grid_search = GridSearchCV(dt, param_grid, cv=5)

grid_search.fit(x_train, y_train)

# Get the best set of hyperparameters
print("Best parameters: ", grid_search.best_params_)
# Out:
# Best parameters:  {'max_depth': 10, 'min_samples_leaf': 4}

# %%
dt = DecisionTreeRegressor(max_depth= 10, min_samples_leaf= 4)

dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=10, min_samples_leaf=4)

# %%
pred_DTG = dt.predict(x_test)
pred_DTG
# Out:
# array([ 54.67105263, 278.33333333,  48.56060606, ...,  88.50152905,
#         69.71209213,  78.29268293])

# %%
print(r2_score(y_test, pred_DTG).round(2)*100,"%") # R-Squared Evaluation Technique
# Out:
# 20.0 %

# %%
param_grid = {
    'n_estimators': [100, 200, 500],
    'max_depth': [None, 5, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

rf = RandomForestRegressor()

# Create a grid search object
grid_search = GridSearchCV(rf, param_grid, cv=5)

y_train_col = y_train.ravel()

# Fit the grid search to the training data
grid_search.fit(x_train, y_train_col)

# Get the best set of hyperparameters
print("Best parameters: ", grid_search.best_params_)

# Get the best random forest regression model
best_rf_reg = grid_search.best_estimator_

# %%
rf = RandomForestRegressor(max_depth= None, min_samples_leaf= 1, min_samples_split= 2, n_estimators= 100)
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred_RFG = rf.predict(x_test)
pred_RFG
# Out:
# array([ 53.3, 119.5,  49.8, ...,  61.6,  67.1,  71. ])

# %%
# Mean square error (MSE) is the average of the square of the errors. The larger the number the larger the error.
mse = mean_squared_error(y_test,pred_RFG)
rmse = np.sqrt(mse)
rmse
# Out:
# 67.12286821603725

# %%
# The r2 score varies between 0 and 100%
print(r2_score(y_test, pred_RFG).round(2)*100,"%") # R-Squared Evaluation Technique
# Out:
# 55.00000000000001 %

# %%
best = rf

# %%
import pickle 

pickle.dump(dt, open("energy.pkl","wb"))
